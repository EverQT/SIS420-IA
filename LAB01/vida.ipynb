# %% [markdown]
# WHO Life Expectancy Data (Datos de Esperanza de Vida de la OMS) = A travez de este datasets se quiere obtener un funcion matemarica que predice la esperanza de vida (Life expectancy) usando una sola vairable Mortalidad adulta (Adult mortality)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/SIS420-IA/datasets/Life Expectancy Data.csv')
data
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
print(data.dtypes)
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
print(data.columns.tolist()) #Lista de columnas
# Out:
# ['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years', ' thinness 5-9 years', 'Income composition of resources', 'Schooling']

# %%
data.columns = data.columns.str.strip() #Limpieza de nombres de columnas
print(data.columns.tolist())
# Out:
# ['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years', 'thinness 5-9 years', 'Income composition of resources', 'Schooling']

# %%
X = data['Adult Mortality'].values.reshape(-1, 1)
y = data['Life expectancy'].values.reshape(-1, 1)

m = y.size  # m = numero de ejemplos de entrenamiento

# %%
print(X)
print(y)
print(X.size)
# Out:
# [[263.]
#  [271.]
#  [268.]
#  ...
#  [ 73.]
#  [686.]
#  [665.]]
# [[65. ]
#  [59.9]
#  [59.9]
#  ...
#  [44.8]
#  [45.3]
#  [46. ]]
# 2938

# %%
import matplotlib.pyplot as plt

def plotData(X, y):
  fig = plt.figure()

  plt.plot(X, y, 'ro', ms=10, mec='k')
  plt.ylabel('Life expectancy')
  plt.xlabel('Adult Mortality')

# %%
plotData(X, y)

# %%
import numpy as np
#print(np.isnan(X).sum())

# Extraer columnas como arrays
X_raw = data['Adult Mortality'].values
y_raw = data['Life expectancy'].values

# Crear máscara para eliminar NaN en ambos
mask = ~np.isnan(X_raw) & ~np.isnan(y_raw)

# Aplicar máscara
X = X_raw[mask].reshape(-1, 1)
y = y_raw[mask].reshape(-1, 1)

# %%
#X = X[~np.isnan(X)]
#X = X.reshape(-1, 1)

print(X.shape)  # (2928, 1)
print(y.shape)  # (2928, 1)
# Out:
# (2928, 1)
# (2928, 1)

# %%
#print(np.std(X))

# %%
#import numpy as np

def featureNormalize(X):
  X = np.array(X, dtype=np.float64)
  X_norm = X.copy()
  mu = np.zeros(X.shape[1])

  mu = np.mean(X, axis = 0)
  sigma = np.std(X, axis = 0)
  X_norm = (X - mu)/ sigma

  return X_norm, mu, sigma

# %%
X_norm, mu, sigma = featureNormalize(X)
print(X_norm)
# Out:
# [[ 0.79023802]
#  [ 0.85461353]
#  [ 0.83047271]
#  ...
#  [-0.73868044]
#  [ 4.19409332]
#  [ 4.02510759]]

# %%
m, n = X_norm.shape
X = np.concatenate([np.ones((m, 1)), X_norm], axis=1)

# %%
X
# Out:
# array([[ 1.        ,  0.79023802],
#        [ 1.        ,  0.85461353],
#        [ 1.        ,  0.83047271],
#        ...,
#        [ 1.        , -0.73868044],
#        [ 1.        ,  4.19409332],
#        [ 1.        ,  4.02510759]])

# %%
def calcularCosto(X, y, theta):
  m = y.size
  J = 0
  J = (1 /(2 * m)) * np.sum(np.square(np.dot(X, theta) - y))

  return J

#def calcular_costo(theta, X, y):
#  m = len(y)
#  h = X.dot(theta)
#  errores = h - y
#  J = (1 / (2 * m)) * np.dot(errores.T, errores)
#  return J.item()
#

# %%
y = y.flatten() # Convierte un arreglo multidimensional en un vector unidimensional

# %%
def gradientDescent(X, y, theta, alpha, num_iters):
  m = y.shape[0]
  theta = theta.copy()

  J_history = []

  for i in range(num_iters):
    theta = theta - (alpha / m) * (np.dot(X, theta) - y).dot(X)
    J_history.append(calcularCosto(X, y, theta))

  return theta, J_history

# %%
# inicializa los parametros de ajuste
theta = np.zeros(2)

# configuraciones para el descenso por el gradiente
iterations = 500000
alpha = 0.001

theta, J_history = gradientDescent(X ,y, theta, alpha, iterations)
print('Theta encontrada por descenso gradiente: {:.4f}, {:.4f}'.format(*theta))
print('Valores theta esperados (aproximadamente): [-3.6303, 1.1664]')
print(J_history)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# grafica la linea de ajuste
plotData(X[:, 1], y)
plt.plot(X[:, 1], np.dot(X, theta), '-')
plt.legend(['Datos de entrenamiento', 'Regresión linear']);

# %%
# Predecir valores de beneficio para poblaciones de 35,000 y 70,000
predict1 = np.dot([1, 8.47], theta)
print('Para una población = 84,700, se predice un beneficio de {:.2f}\n'.format(predict1*10000))

predict2 = np.dot([1, 9], theta)
print('Para una población de = 90,000, se predice un beneficio de {:.2f}\n'.format(predict2*10000))
# Out:
# Para una población = 84,700, se predice un beneficio de 130611.98
#
# Para una población de = 90,000, se predice un beneficio de 95468.21
